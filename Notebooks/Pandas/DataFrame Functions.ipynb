# %% [markdown]
# # __Data Frame Functions__

# %%
import pandas as pd
import numpy as np

# %%
data = {
    'EmpID': [101, 102, 102, 104, 105, 106, 107, 108, 109, 110],
    'Name': ['Ali', 'Sara', None, 'Zara', 'Usman', 'Hina', 'Bilal', 'Nida', 'Omer', 'Ayesha'],
    'Dept': ['IT', 'hr', 'IT ', 'Finance', 'Sales', 'it', 'HR', 'Marketing', 'Finance', 'IT'],
    'Salary': ['45,000', '52000', '48k', '60,000', None, '47,000', '55,000', '62,000', '58000', '50k'],
    'Experience': [1, 5, np.nan, 7, 3, 1, 4, np.nan, 8, 2],
    'JoinDate': ['2021-01-10', '2018/05/20', None, '2016-03-15', '2019-07-01', 
                 '2022-02-11', '2017/08/30', '2015-06-05', '2014-11-25', '2020-09-01']
}

# %%
df = pd.DataFrame(data)

df['Dept'] = df['Dept'].str.upper().str.strip()
# Validation using .isin()
valid_Depts = ['IT', 'HR', 'FINANCE', 'MARKETING']
df.loc[~df['Dept'].isin(valid_Depts),'Dept']=None

# Using Replace Function
df=df.replace({'Salary':'k'},'000',regex=True)
df=df.replace({'Salary':','},'',regex=True)

# Using str.replace
df['Salary'] = df['Salary'].str.replace('k','000').str.replace(',','')
df['Salary']=pd.to_numeric(df['Salary'])
df['Salary']=df['Salary'].fillna(df['Salary'].median())
df['Salary']=df['Salary'].astype(int)

df['Salary']

globalExpMean=df['Experience'].mean()

s=df.groupby('Dept')['Experience'].transform('mean')
df['Experience']=df['Experience'].fillna(s)
df['Experience']=df['Experience'].fillna(globalExpMean)
df['Experience']=df['Experience'].round(2)
df

df['JoinDate']=df['JoinDate'].str.replace('/','-')
df['JoinDate']=pd.to_datetime(df['JoinDate'])

df.dropna(subset=['Name'])
df.reset_index(drop=True)
# Out:
#    EmpID    Name       Dept  Salary  Experience   JoinDate
# 0    101     Ali         IT   45000        1.00 2021-01-10
# 1    102    Sara         HR   52000        5.00 2018-05-20
# 2    102    None         IT   48000        1.33        NaT
# 3    104    Zara    FINANCE   60000        7.00 2016-03-15
# 4    105   Usman       None   52000        3.00 2019-07-01
# 5    106    Hina         IT   47000        1.00 2022-02-11
# 6    107   Bilal         HR   55000        4.00 2017-08-30
# 7    108    Nida  MARKETING   62000        3.88 2015-06-05
# 8    109    Omer    FINANCE   58000        8.00 2014-11-25
# 9    110  Ayesha         IT   50000        2.00 2020-09-01

# %% [markdown]
# ---
#  ## __1. Creation & Basic Info (Understand Your Data)__

# %% [markdown]
# ###  pd.DataFrame() Create DataFrame From dict, list, ndarray

# %%
df = pd.DataFrame(data)

# %% [markdown]
# ### df.head(n) First n rows Quick preview

# %%
df.head(4)
# Out:
#    EmpID  Name     Dept  Salary  Experience    JoinDate
# 0    101   Ali       IT  45,000         1.0  2021-01-10
# 1    102  Sara       hr   52000         5.0  2018/05/20
# 2    102  None      IT      48k         NaN        None
# 3    104  Zara  Finance  60,000         7.0  2016-03-15

# %% [markdown]
# ### df.tail(n) Last n rows Check end

# %%
df.tail(5)
# Out:
#    EmpID    Name       Dept  Salary  Experience    JoinDate
# 5    106    Hina         it  47,000         1.0  2022-02-11
# 6    107   Bilal         HR  55,000         4.0  2017/08/30
# 7    108    Nida  Marketing  62,000         NaN  2015-06-05
# 8    109    Omer    Finance   58000         8.0  2014-11-25
# 9    110  Ayesha         IT     50k         2.0  2020-09-01

# %% [markdown]
# ### df.sample(n) Random rows Spot-check data

# %%
df.sample(5)
# Out:
#    EmpID    Name   Dept  Salary  Experience    JoinDate
# 6    107   Bilal     HR  55,000         4.0  2017/08/30
# 4    105   Usman  Sales    None         3.0  2019-07-01
# 9    110  Ayesha     IT     50k         2.0  2020-09-01
# 0    101     Ali     IT  45,000         1.0  2021-01-10
# 2    102    None    IT      48k         NaN        None

# %% [markdown]
# ### df.shape : (rows, cols) Dataset size

# %%
df.shape
# Out:
# (10, 6)

# %% [markdown]
# ### df.size :Total cells Memory idea

# %%
df.size
# Out:
# 60

# %% [markdown]
# ### df.ndim Dimensions Usually 2

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# ### df.info() Columns, dtypes, nulls MOST IMPORTANT

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmpID       10 non-null     int64
#  1   Name        9 non-null      object
#  2   Dept        10 non-null     object
#  3   Salary      9 non-null      object
#  4   Experience  8 non-null      float64
#  5   JoinDate    9 non-null      object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 612.0+ bytes

# %% [markdown]
# ### df.describe() Stats summary Numeric overview

# %%
df.describe()
# Out:
#             EmpID  Experience
# count   10.000000    8.000000
# mean   105.400000    3.875000
# std      3.134042    2.642374
# min    101.000000    1.000000
# 25%    102.500000    1.750000
# 50%    105.500000    3.500000
# 75%    107.750000    5.500000
# max    110.000000    8.000000

# %% [markdown]
# ### df.columns Column names Rename, inspect

# %%
df.columns
# Out:
# Index(['EmpID', 'Name', 'Dept', 'Salary', 'Experience', 'JoinDate'], dtype='object')

# %% [markdown]
# ### df.index Index object Reset/align

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %% [markdown]
# ---
# ## __2. Column & Index Operations__

# %% [markdown]
# ### df['col'] Select column (Series)

# %%
df['Name']
# Out:
# 0       Ali
# 1      Sara
# 2      None
# 3      Zara
# 4     Usman
# 5      Hina
# 6     Bilal
# 7      Nida
# 8      Omer
# 9    Ayesha
# Name: Name, dtype: object

# %% [markdown]
# ### df[['c1','c2']] Multiple columns

# %%
df[['EmpID','Name']]
# Out:
#    EmpID    Name
# 0    101     Ali
# 1    102    Sara
# 2    102    None
# 3    104    Zara
# 4    105   Usman
# 5    106    Hina
# 6    107   Bilal
# 7    108    Nida
# 8    109    Omer
# 9    110  Ayesha

# %% [markdown]
# ### df.rename(columns/index={Name:NewName}) : Rename columns/index

# %%
df.rename(columns={"JoinDate":"JoiningDate"})
df.rename(index={2:4})
# Out:
#    EmpID    Name       Dept  Salary  Experience    JoinDate
# 0    101     Ali         IT  45,000         1.0  2021-01-10
# 1    102    Sara         hr   52000         5.0  2018/05/20
# 4    102    None        IT      48k         NaN        None
# 3    104    Zara    Finance  60,000         7.0  2016-03-15
# 4    105   Usman      Sales    None         3.0  2019-07-01
# 5    106    Hina         it  47,000         1.0  2022-02-11
# 6    107   Bilal         HR  55,000         4.0  2017/08/30
# 7    108    Nida  Marketing  62,000         NaN  2015-06-05
# 8    109    Omer    Finance   58000         8.0  2014-11-25
# 9    110  Ayesha         IT     50k         2.0  2020-09-01

# %% [markdown]
# ### df.set_index() Set column as index

# %%
df.set_index("EmpID")
# Out:
#          Name       Dept  Salary  Experience    JoinDate
# EmpID
# 101       Ali         IT  45,000         1.0  2021-01-10
# 102      Sara         hr   52000         5.0  2018/05/20
# 102      None        IT      48k         NaN        None
# 104      Zara    Finance  60,000         7.0  2016-03-15
# 105     Usman      Sales    None         3.0  2019-07-01
# 106      Hina         it  47,000         1.0  2022-02-11
# 107     Bilal         HR  55,000         4.0  2017/08/30
# 108      Nida  Marketing  62,000         NaN  2015-06-05
# 109      Omer    Finance   58000         8.0  2014-11-25
# 110    Ayesha         IT     50k         2.0  2020-09-01

# %% [markdown]
# ### df.reset_index(drop=True) Reset index

# %%
df.reset_index(drop=True)
# Out:
#    EmpID    Name       Dept  Salary  Experience    JoinDate
# 0    101     Ali         IT  45,000         1.0  2021-01-10
# 1    102    Sara         hr   52000         5.0  2018/05/20
# 2    102    None        IT      48k         NaN        None
# 3    104    Zara    Finance  60,000         7.0  2016-03-15
# 4    105   Usman      Sales    None         3.0  2019-07-01
# 5    106    Hina         it  47,000         1.0  2022-02-11
# 6    107   Bilal         HR  55,000         4.0  2017/08/30
# 7    108    Nida  Marketing  62,000         NaN  2015-06-05
# 8    109    Omer    Finance   58000         8.0  2014-11-25
# 9    110  Ayesha         IT     50k         2.0  2020-09-01

# %% [markdown]
# ### df.insert(index, "Name", value) Insert column at position

# %%
age=pd.Series(np.random.randint(20,30,10))
df.insert(3,"Age",age)

# %% [markdown]
# ### df.pop() Remove & return column

# %%
age=df.pop("Age")

# %% [markdown]
# ### df.drop() Drop rows or columns

# %%
df.drop("Dept",axis=1)
df.drop(4,axis=0)
# Out:
#    EmpID    Name       Dept  Salary  Experience    JoinDate
# 0    101     Ali         IT  45,000         1.0  2021-01-10
# 1    102    Sara         hr   52000         5.0  2018/05/20
# 2    102    None        IT      48k         NaN        None
# 3    104    Zara    Finance  60,000         7.0  2016-03-15
# 5    106    Hina         it  47,000         1.0  2022-02-11
# 6    107   Bilal         HR  55,000         4.0  2017/08/30
# 7    108    Nida  Marketing  62,000         NaN  2015-06-05
# 8    109    Omer    Finance   58000         8.0  2014-11-25
# 9    110  Ayesha         IT     50k         2.0  2020-09-01

# %% [markdown]
# ---
# ## __3. Selection & Filtering__
#     Label / Position Based

# %% [markdown]
# ### df.loc[index]['Col'] Label-based (SAFE)

# %%
df.loc[0]['Name']
df.loc[0]
# Out:
# EmpID                101
# Name                 Ali
# Dept                  IT
# Salary            45,000
# Experience           1.0
# JoinDate      2021-01-10
# Name: 0, dtype: object

# %% [markdown]
# ### df.iloc[index]['Col'] Position-based

# %%
df.iloc[0]['Name']
df.iloc[0]
# Out:
# EmpID                101
# Name                 Ali
# Dept                  IT
# Salary            45,000
# Experience           1.0
# JoinDate      2021-01-10
# Name: 0, dtype: object

# %% [markdown]
# ### df.at[row-index, col-index] Fast single value

# %%
df.at[0,'Name']
# Out:
# 'Ali'

# %% [markdown]
# ### df.iat[row-index,col-Index] Fast positional value

# %%
df.iat[0,1]
# Out:
# 'Ali'

# %% [markdown]
# ### Boolean Filtering
#
# | Pattern | Meaning |
# | --- | --- |
# | `df[df['col'] > x]` | Filter rows based on value |
# | `df.loc[cond, cols]` | **SAFE** filter + modify (Selects specific rows/cols) |
# | `(cond1) & (cond2)` | Bitwise **AND** (Both conditions must be true) |
# | `(cond1) | (cond2)` |
# | `~cond` | Bitwise **NOT** (Inverses the condition) |

# %%
df[df['Experience']>2]
# Out:
#    EmpID   Name     Dept  Salary  Experience    JoinDate
# 1    102   Sara       hr   52000         5.0  2018/05/20
# 3    104   Zara  Finance  60,000         7.0  2016-03-15
# 4    105  Usman    Sales    None         3.0  2019-07-01
# 6    107  Bilal       HR  55,000         4.0  2017/08/30
# 8    109   Omer  Finance   58000         8.0  2014-11-25

# %%
df.loc[df['Experience']>2,'Salary']=50000

# %%
df[(df['Experience']>2) & (df['JoinDate']<'2018-01-01')]
# Out:
#    EmpID   Name     Dept Salary  Experience    JoinDate
# 3    104   Zara  Finance  50000         7.0  2016-03-15
# 6    107  Bilal       HR  50000         4.0  2017/08/30
# 8    109   Omer  Finance  50000         8.0  2014-11-25

# %%
df[~(df['Dept']=='IT')]
# Out:
#    EmpID   Name       Dept  Salary  Experience    JoinDate
# 1    102   Sara         hr   50000         5.0  2018/05/20
# 2    102   None        IT      48k         NaN        None
# 3    104   Zara    Finance   50000         7.0  2016-03-15
# 4    105  Usman      Sales   50000         3.0  2019-07-01
# 5    106   Hina         it  47,000         1.0  2022-02-11
# 6    107  Bilal         HR   50000         4.0  2017/08/30
# 7    108   Nida  Marketing  62,000         NaN  2015-06-05
# 8    109   Omer    Finance   50000         8.0  2014-11-25

# %% [markdown]
# ---
# ## __4. Modification / Assignment__
#
# | Method | Purpose |
# | --- | --- |
# | `df.loc[cond, col] = val` | **Conditional update** (Modifies specific rows/cols in place) |
# | `df[col] = ...` | **Create/Overwrite** an entire column |
# | `df.assign()` | **Create new column safely** (Returns a new DataFrame with added Columns; original is untouched) |
# | `df.update()` | **Update** values using data from another DataFrame (Modifies directly by indexes of rows) |
#
#
# ---
#
# #### ⚠️ Best Practice: Avoiding "Chained Assignment"
#
# Pandas cannot always guarantee whether you are modifying a **view** or a **copy** when you chain slice operations. Always use `.loc` for conditional updates.
#
# **Avoid (WRONG)**
#
# > `df[df['Stock'] < 50]['Price'] = 999`
# > *Risk: May raise `SettingWithCopyWarning` and fail to update the original DataFrame.*
#
# **Correct (SAFE)**
#
# > `df.loc[df['Stock'] < 50, 'Price'] = 99`
# > *Result: Explicitly targets the rows and column in a single step.*
#
# ---

# %%
df.loc[df['Dept']=='IT','Salary']*=1.10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Professor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File c:\Users\Professor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Users\Professor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: can't multiply sequence by non-int of type 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df.loc[df['Dept']=='IT','Salary']*=1.10
#
# File c:\Users\Professor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:12748, in NDFrame.__imul__(self, other)
#   12745 @final
#   12746 def __imul__(self, other) -> Self:
#   12747     # error: Unsupported left operand type for * ("Type[NDFrame]")
# > 12748     return self._inplace_method(other, type(self).__mul__)
#
# File c:\Users\Professor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:12708, in NDFrame._inplace_method(self, other, op)
#   12704     if sys.getrefcount(self) <= REF_COUNT + 2:
#   12705         # we are probably in an inplace setitem context (e.g. df['a'] += 1)
#   12706         warn = False
# > 12708 result = op(self, other)
#   12710 if (
#   12711     self.ndim == 1
#   12712     and result._indexed_same(self)
#    (...)  12718     # Item "ArrayManager" of "Union[ArrayManager, SingleArrayManager,
#   12719     # BlockManager, SingleBlockManager]" has no attribute "setitem_inplace"
#   12720     self._mgr.setitem_inplace(  # type: ignore[union-attr]
#   12721         slice(None), result._values, warn=warn
#   12722     )
#
# File c:\Users\Professor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Users\Professor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arraylike.py:202, in OpsMixin.__mul__(self, other)
#     200 @unpack_zerodim_and_defer("__mul__")
#     201 def __mul__(self, other):
# --> 202     return self._arith_method(other, operator.mul)
#
# File c:\Users\Professor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:6146, in Series._arith_method(self, other, op)
#    6144 def _arith_method(self, other, op):
#    6145     self, other = self._align_for_op(other)
# -> 6146     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File c:\Users\Professor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\base.py:1391, in IndexOpsMixin._arith_method(self, other, op)
#    1388     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1390 with np.errstate(all="ignore"):
# -> 1391     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1393 return self._construct_result(result, name=res_name)
#
# File c:\Users\Professor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\array_ops.py:283, in arithmetic_op(left, right, op)
#     279     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     281     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     282     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 283     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     285 return res_values
#
# File c:\Users\Professor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\array_ops.py:227, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)    225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
# --> 227         result = _masked_arith_op(left, right, op)
#     228     else:
#     229         raise
#
# File c:\Users\Professor\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\ops\array_ops.py:182, in _masked_arith_op(x, y, op)
#     179         mask = np.where(y == 1, False, mask)
#     181     if mask.any():
# --> 182         result[mask] = op(xrav[mask], y)
#     184 np.putmask(result, ~mask, np.nan)
#     185 result = result.reshape(x.shape)  # 2D compat
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
df['Age']=np.random.randint(20,30,10)
df['Dept']=np.random.choice(['IT','HR','FINANCE'], size=10)

# %%
df.assign(
    Bonus_Eligible = lambda x: x['Experience'] > 3.0
)

# %%
corrections = pd.DataFrame({
    'Dept': {1: 'HR', 5: 'IT'},
    'Name': {2: 'Ahmed'}
})
df.update(corrections)

# %% [markdown]
# ---
# ## __5. Missing Data Handling__

# %% [markdown]
# ### df.isna() / df.isnull() : Detect NaNs

# %%
df.isna()
df.isnull()

# %% [markdown]
# ### df.notna() : Opposite (Only checks NOT NaN)

# %%
df.notna()

# %% [markdown]
# ### df.dropna() :   Remove Rows/Columns containing missing values
#
#
#
# ### `dropna()` Parameters
#
# | Parameter | Meaning |
# | --- | --- |
# | `axis=0` / `1` | Drop **rows** (0) or **columns** (1) |
# | `how='any'` | Drop if **any** value is `NaN` (Default) |
# | `how='all'` | Drop if **all** values are `NaN` |
# | `thresh=n` | Keep rows/cols with **at least n** non-NaN values |
# | `subset=[cols]` | Consider only these specific columns for `NaN` checks |
#
# ---

# %%
df.dropna()
df.dropna(axis=1)
df.dropna(how='all')
df.dropna(how='any')
df.dropna(thresh=2)
df.dropna(subset=['JoinDate'])

# %% [markdown]
# ### df.fillna() : Fill missing

# %%
df.fillna(0)

# %% [markdown]
# ### df.interpolate() : Estimate values

# %%
df.interpolate()

# %% [markdown]
# ### df.replace() : Replace specific values

# %%
df.replace(to_replace='HR',value='CS')

# %% [markdown]
# ---
# ## __6. String Operations (.str)__

# %% [markdown]
# ### df['col'].str.lower() :  lowercase

# %%
df['Name'].str.lower()

# %% [markdown]
# ### str.upper() :  uppercase

# %%
df['Name'].str.upper()

# %% [markdown]
# ### str.strip() : remove spaces

# %%
df['Name'].str.strip()

# %% [markdown]
# ### str.replace() : regex replace

# %%
df['Salary'].str.replace(',','').str.replace('k','000')

# %% [markdown]
# ### str.contains() :  filter text

# %%
df['Name'].str.contains('Ali')

# %% [markdown]
# ### str.startswith() : prefix

# %%
df['Name'].str.startswith('A')

# %% [markdown]
# ### str.endswith() :  suffix

# %%
df['Name'].str.endswith('a')

# %% [markdown]
# ### str.split() :  split string

# %%
df['Name'].str.split("")

# %% [markdown]
# ---
# ## __7. Type Conversion & Cleaning__

# %% [markdown]
# ### df.astype() : Change dtype

# %%
df['Experience'].astype(str)

# %% [markdown]
# ### pd.to_numeric() : Clean numbers

# %%
pd.to_numeric(df['Experience'])

# %% [markdown]
# ### pd.to_datetime() : Parse dates

# %%
df['JoinDate']=df['JoinDate'].str.replace('/','-')
pd.to_datetime(df['JoinDate'])

# %% [markdown]
# ### df.convert_dtypes() : Smart dtype inference

# %%
df.convert_dtypes()

# %% [markdown]
# ---
# ## __8. Sorting & Ranking__

# %% [markdown]
# ### df.sort_values(by=) : Sort rows

# %%
df.sort_values(by='Experience',ascending=False)

# %% [markdown]
# ### df.sort_index():  Sort index

# %%
df.sort_index()

# %% [markdown]
# ### df.rank(): Ranking

# %%
df.select_dtypes(include='number').rank()

# %% [markdown]
# ### df.nlargest(n, col) :  Top values

# %%
df.nlargest(3,'Salary')

# %% [markdown]
# ### df.nsmallest(n, col) : Bottom values

# %%
df.nsmallest(3,'Salary')

# %% [markdown]
# ---
# ## __9. Grouping & Aggregation__

# %% [markdown]
# ### df.groupby() Group data

# %%
df.groupby('Dept')['EmpID'].count()

# %% [markdown]
# ### Pandas Aggregate Functions
#
# | Method | Description |
# | --- | --- |
# | `df.mean()` | Returns the **average** of all values |
# | `df.sum()` | Returns the **sum** of values |
# | `df.count()` | Returns the count of **non-null** values |
# | `df.median()` | Returns the **median** (middle value) |
# | `df.min()` | Returns the **minimum** value |
# | `df.max()` | Returns the **maximum** value |
# | `df.std()` | Returns the **standard deviation** |
# | `df.var()` | Returns the **variance** |
# | `df.mode()` | Returns the **mode** (most frequent value) |
# | `df.describe()` | Generates summary statistics (count, mean, std, min, 25%, 50%, 75%, max) |

# %%
df['EmpID'].count()
df['Experience'].sum()
df['Salary'].min()
df['Salary'].max()
df['Salary'].median()
df['Salary'].mean()
df.describe()

# %% [markdown]
# ### agg(['sum','mean']): Multiple agg

# %%
df['Salary'].agg([ 'sum','mean','count'])

# %% [markdown]
# ### transform() : Per-row group calc

# %%
df.groupby('Dept')['Salary'].transform('mean')

# %% [markdown]
# ### filter() :  Filter groups
#
# The `df.filter()` function in Pandas is used to select columns or rows based on their **names (labels)**, not their values.
#
# > **Crucial Distinction:** `df.filter()` looks at **Column Headers** or **Index Labels**. It does *not* filter the actual data inside the cells (for that, use Boolean Filtering like `df[df['col'] > 5]`).
#
# ### `filter()` Parameters
#
# | Parameter | Function | Example |
# | --- | --- | --- |
# | `items=[list]` | Selects columns with **exact** names | `items=['Name', 'Salary']` |
# | `like='string'` | Selects columns containing this **substring** | `like='Sal'` (Matches 'Salary', 'Sales') |
# | `regex='pattern'` | Selects columns matching a **Regex** pattern | `regex='e$'` (Ends with 'e') |
# | `axis=0/1` | **1** for Columns (Default), **0** for Rows (Index) | `axis=0` filters row labels |

# %%
df.filter(items=['Name','Salary'])
df.filter(like='a')
df.filter(regex=',')
df.filter(items=['Name','Dept'],axis=1)

# %% [markdown]
# ---
# ## __10. Duplicates & Uniqueness__

# %% [markdown]
# ###   __`df.duplicated()`__
#
# **Purpose:**
# Returns a **Boolean Series** indicating whether each row is a duplicate.
#
# ### Parameters
#
# | Parameter | Default   | Description                                                                                                                                                  |
# | --------- | --------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------ |
# | `subset`  | `None`    | Columns to consider when identifying duplicates. If `None`, all columns are used.                                                                            |
# | `keep`    | `'first'` | `'first'` → First occurrence is `False`, others `True`<br>`'last'` → Last occurrence is `False`, others `True`<br>`False` → **All** duplicates marked `True` |

# %%
df.duplicated(subset=['EmpID'])

# %% [markdown]
# ###  __`df.drop_duplicates()`__
#
# **Purpose:**
# Removes duplicate rows and returns a cleaned DataFrame.
#
# ### Parameters
#
# | Parameter      | Default   | Description                                                                                               |
# | -------------- | --------- | --------------------------------------------------------------------------------------------------------- |
# | `subset`       | `None`    | Columns to check for duplicates                                                                           |
# | `keep`         | `'first'` | `'first'` → Keep first occurrence<br>`'last'` → Keep last occurrence<br>`False` → Drop **all** duplicates |
# | `inplace`      | `False`   | `True` → Modify DataFrame directly<br>`False` → Return new DataFrame                                      |
# | `ignore_index` | `False`   | `True` → Reset index after removal<br>`False` → Keep original index                                       |

# %%
df.drop_duplicates(subset=['EmpID'])

# %% [markdown]
# ###  __`df.nunique()`__
#
# **Purpose:**
# Counts **unique values** along a given axis.
#
# ### Parameters
#
# | Parameter | Default | Description                                                                       |
# | --------- | ------- | --------------------------------------------------------------------------------- |
# | `axis`    | `0`     | `0` → Count unique values **per column**<br>`1` → Count unique values **per row** |
# | `dropna`  | `True`  | `True` → Ignore `NaN` values<br>`False` → Count `NaN` as a unique value           |

# %%
df.nunique(axis=0)
# df.nunique(axis=1)

# %% [markdown]
# ###  __`Series.unique()`__
#
# **Purpose:**
# Returns **unique values** from a single column.
#
# ### Notes
#
# * Works **only on Series**, not DataFrames
# * Returns a **NumPy array**
# * Includes `NaN` values

# %%
df['Name'].unique()

# %% [markdown]
# ---
# ## __11. Merge / Join / Combine__
# #### 🔍 Quick Comparison Table
#
# | Method            | Join Type   | Based On        | Common Use            |
# | ----------------- | ----------- | --------------- | --------------------- |
# | `pd.merge()`      | SQL-like    | Column          | Relational data       |
# | `df.join()`       | Simple join | Index           | Fast index joins      |
# | `pd.concat()`     | Stack       | Axis            | Append / combine data |
# | `combine_first()` | Fill        | Index + columns | Missing data recovery |

# %% [markdown]
# ###  `pd.merge()` — **SQL-like joins**
#
# #### Parameters
#
# | Parameter   | Default       | Meaning                                   |
# | ----------- | ------------- | ----------------------------------------- |
# | `left`      | —             | Left DataFrame                            |
# | `right`     | —             | Right DataFrame                           |
# | `on`        | `None`        | Column(s) to join on                      |
# | `how`       | `'inner'`     | `'inner'`, `'left'`, `'right'`, `'outer'` |
# | `left_on`   | `None`        | Left column if names differ               |
# | `right_on`  | `None`        | Right column if names differ              |
# | `suffixes`  | `('_x','_y')` | Rename overlapping columns                |
# | `indicator` | `False`       | Adds column showing source (`_merge`)     |

# %%
customers = pd.DataFrame({
    'cust_id': [1, 2, 3],
    'name': ['Ali', 'Sara', 'Usman']
})

orders = pd.DataFrame({
    'cust_id': [1, 1, 2, 4],
    'order_id': [101, 102, 103, 104]
})

pd.merge(customers, orders, on='cust_id', how='inner')

# %% [markdown]
# ###  `df.join()` — **Index-based join**
#
# ### 👉 Important Parameters
#
# | Parameter | Default  | Meaning                                   |
# | --------- | -------- | ----------------------------------------- |
# | `other`   | —        | DataFrame to join                         |
# | `on`      | `None`   | Join key if not index                     |
# | `how`     | `'left'` | `'left'`, `'right'`, `'inner'`, `'outer'` |
# | `lsuffix` | `''`     | Left suffix for conflicts                 |
# | `rsuffix` | `''`     | Right suffix for conflicts                |
#
# 📌 **Best when index is meaningful**

# %%
users = pd.DataFrame({
    'name': ['Ali', 'Sara', 'Usman']
}, index=[1, 2, 3])

scores = pd.DataFrame({
    'score': [85, 90]
}, index=[1, 3])

users.join(scores)

# %% [markdown]
# ###  `pd.concat()` — **Stack or append data**
#
# ### 👉 Important Parameters
#
# | Parameter      | Default   | Meaning                   |
# | -------------- | --------- | ------------------------- |
# | `objs`         | —         | List of DataFrames        |
# | `axis`         | `0`       | `0` → rows, `1` → columns |
# | `ignore_index` | `False`   | Reset index               |
# | `join`         | `'outer'` | `'outer'` or `'inner'`    |
# | `keys`         | `None`    | Create hierarchical index |

# %%
df1 = pd.DataFrame({
    'id': [1, 3],
    'name': ['Ali', 'Sara']
})

df2 = pd.DataFrame({
    'id': [2],
    'name': ['Usman']
})

pd.concat([df1,df2])

# %% [markdown]
# ###  `combine_first()` — **Fill missing values from another DataFrame**
#
#
#
# #### 👉 Parameters
#
# | Parameter | Meaning                               |
# | --------- | ------------------------------------- |
# | `other`   | DataFrame used to fill missing values |
#
# 📌 **Works index + column wise**
#
# 📌 Does **not overwrite existing non-NaN values**

# %%
df_a = pd.DataFrame({
    'name': ['Ali', None, 'Usman'],
    'age': [20, None, 23]
})

df_b = pd.DataFrame({
    'name': ['Ali', 'Sara', 'Usman'],
    'age': [20, 22, 23]
})

df_a.combine_first(df_b)

# %% [markdown]
# ---
# ## __12. Apply / Vectorization__

# %% [markdown]
# ### `df.apply()` -- **Row-wise / Column-wise logic**
#
# #### 📌 When to use
#
# * Complex logic involving **multiple columns**
# * When vectorized solution is not possible
#
# ### 👉 Important Parameters
#
# | Parameter     | Default | Meaning                               |
# | ------------- | ------- | ------------------------------------- |
# | `func`        | —       | Function to apply                     |
# | `axis`        | `0`     | `0` → column-wise<br>`1` → row-wise   |
# | `result_type` | `None`  | `'expand'`, `'reduce'`, `'broadcast'` |
# | `raw`         | `False` | Pass ndarray instead of Series        |
#
# ⚠️ **Slower than vectorized operations**

# %%
# column wise logic
marks=pd.Series([2,3,4])
marks.apply(lambda x: x*x)

# row wise logic  Structure : Lambda x: value_if_true if condition else value_if_false
df['Seniority']=df.apply(lambda row: 'Senior' if row['Experience']>5 else 'Junior',axis=1)
df
# Out:
#    EmpID    Name       Dept  Salary  Experience   JoinDate Seniority
# 0    101     Ali         IT   45000        1.00 2021-01-10    Junior
# 1    102    Sara         HR   52000        5.00 2018-05-20    Junior
# 2    102    None         IT   48000        1.33        NaT    Junior
# 3    104    Zara    FINANCE   60000        7.00 2016-03-15    Senior
# 4    105   Usman       None   52000        3.00 2019-07-01    Junior
# 5    106    Hina         IT   47000        1.00 2022-02-11    Junior
# 6    107   Bilal         HR   55000        4.00 2017-08-30    Junior
# 7    108    Nida  MARKETING   62000        3.88 2015-06-05    Junior
# 8    109    Omer    FINANCE   58000        8.00 2014-11-25    Senior
# 9    110  Ayesha         IT   50000        2.00 2020-09-01    Junior

# %% [markdown]
# ###  `df.map()` — **Element-wise (Series only)**
#
# #### 📌 When to use
#
# * Apply function to **each value in a single column**
# * Value transformation or mapping
#
# ### 👉 Important Parameters
#
# | Parameter   | Meaning                      |
# | ----------- | ---------------------------- |
# | `arg`       | Function, dict, or Series    |
# | `na_action` | `'ignore'` → Skip NaN values |
#
# 📌 **Works on Series only**
# 📌 Faster than `apply` (but still not fully vectorized)

# %%
df['Status']=df['Salary'].map(lambda x:'Rich' if x>=50000 else 'Poor' )
df
# Out:
#    EmpID    Name       Dept  Salary  Experience   JoinDate Seniority Status
# 0    101     Ali         IT   45000        1.00 2021-01-10    Junior   Poor
# 1    102    Sara         HR   52000        5.00 2018-05-20    Junior   Rich
# 2    102    None         IT   48000        1.33        NaT    Junior   Poor
# 3    104    Zara    FINANCE   60000        7.00 2016-03-15    Senior   Rich
# 4    105   Usman       None   52000        3.00 2019-07-01    Junior   Rich
# 5    106    Hina         IT   47000        1.00 2022-02-11    Junior   Poor
# 6    107   Bilal         HR   55000        4.00 2017-08-30    Junior   Rich
# 7    108    Nida  MARKETING   62000        3.88 2015-06-05    Junior   Rich
# 8    109    Omer    FINANCE   58000        8.00 2014-11-25    Senior   Rich
# 9    110  Ayesha         IT   50000        2.00 2020-09-01    Junior   Rich

# %% [markdown]
# ### `df.applymap()` — **Element-wise on whole DataFrame**
#
# #### 📌 When to use
#
# * Apply the **same operation to every cell**
# * Rarely needed (mostly replaced by vectorization)
#
# ### 👉 Parameters
#
# | Parameter | Meaning                           |
# | --------- | --------------------------------- |
# | `func`    | Function to apply to each element |
#
# ⚠️ **Slowest of all** → avoid on large DataFrames

# %%
df_numeric = pd.DataFrame({
    'A': [1, 2],
    'B': [3, 4]
})

df_numeric.applymap(lambda x:x*2)
# Out:
# C:\Users\Professor\AppData\Local\Temp\ipykernel_13232\921071976.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_numeric.applymap(lambda x:x*2)
#    A  B
# 0  2  6
# 1  4  8

# %% [markdown]
# ### `np.where()` — **Fast vectorized condition**
#
# #### 📌 When to use
#
# * Conditional logic on arrays / columns
# * Best replacement for many `apply` use-cases
#
#
# ### 👉 Parameters
#
# | Parameter   | Meaning                     |
# | ----------- | --------------------------- |
# | `condition` | Boolean condition           |
# | `x`         | Value if condition is True  |
# | `y`         | Value if condition is False |
#
# 📌 **Fully vectorized → fastest option**

# %%
df['QP']=np.where(df['Experience'] >= 5,3,1)

# %% [markdown]
# ---
# ## __13. Export / Import in Pandas__
#
# #### 🔍 Quick Comparison
#
# | Method         | Direction | File Type | Common Use          |
# | -------------- | --------- | --------- | ------------------- |
# | `to_csv()`     | Export    | CSV       | Lightweight storage |
# | `to_excel()`   | Export    | Excel     | Reports / sharing   |
# | `read_csv()`   | Import    | CSV       | Large datasets      |
# | `read_excel()` | Import    | Excel     | Business data       |
#
# ---

# %% [markdown]
# ##  `df.to_csv()` — **Save DataFrame to CSV**
#
# ### 📌 When to use
#
# * Store cleaned / processed data
# * Share data between systems
#
# ### 👉 Sample DataFrame
#
# ```python
# import pandas as pd
#
# df = pd.DataFrame({
#     'id': [1, 2, 3],
#     'name': ['Ali', 'Sara', 'Usman'],
#     'marks': [85, 90, 78]
# })
# ```
#
# ### 👉 Usage
#
# ```python
# df.to_csv('students.csv', index=False)
# ```
#
# ### 👉 Important Parameters
#
# | Parameter     | Default | Meaning                   |
# | ------------- | ------- | ------------------------- |
# | `path_or_buf` | —       | File path or buffer       |
# | `index`       | `True`  | Write index to file       |
# | `sep`         | `','`   | Column separator          |
# | `header`      | `True`  | Write column names        |
# | `mode`        | `'w'`   | `'w'` write, `'a'` append |
# | `encoding`    | `None`  | File encoding (`'utf-8'`) |

# %% [markdown]
# ###  `df.to_excel()` — **Save DataFrame to Excel**
#
# #### 📌 When to use
#
# * Reports, business sharing
# * Multi-sheet Excel files
#
# #### 👉 Usage
#
# ```python
# df.to_excel('students.xlsx', index=False, sheet_name='Results')
# ```
#
# #### 👉 Important Parameters
#
# | Parameter      | Default    | Meaning                      |
# | -------------- | ---------- | ---------------------------- |
# | `excel_writer` | —          | File path or ExcelWriter     |
# | `sheet_name`   | `'Sheet1'` | Excel sheet name             |
# | `index`        | `True`     | Write index                  |
# | `engine`       | `None`     | `'openpyxl'`, `'xlsxwriter'` |
# | `startrow`     | `0`        | Row to start writing         |
# | `startcol`     | `0`        | Column to start writing      |

# %% [markdown]
# ###  `pd.read_csv()` — **Load CSV into DataFrame**
#
# #### 📌 When to use
#
# * Load raw datasets
# * Read logs, exports, public data
#
# #### 👉 Usage
#
# ```python
# df = pd.read_csv('students.csv')
# ```
#
# #### 👉 Important Parameters
#
# | Parameter            | Default   | Meaning                    |
# | -------------------- | --------- | -------------------------- |
# | `filepath_or_buffer` | —         | File path                  |
# | `sep`                | `','`     | Column delimiter           |
# | `header`             | `'infer'` | Row to use as column names |
# | `names`              | `None`    | Custom column names        |
# | `index_col`          | `None`    | Column as index            |
# | `usecols`            | `None`    | Select specific columns    |
# | `dtype`              | `None`    | Force data types           |
# | `na_values`          | `None`    | Custom missing values      |

# %% [markdown]
# ###  `pd.read_excel()` — **Load Excel into DataFrame**
#
# #### 📌 When to use
#
# * Excel-based datasets
# * Multiple sheets
#
# #### 👉 Usage
#
# ```python
# df = pd.read_excel('students.xlsx', sheet_name='Results')
# ```
#
# #### 👉 Important Parameters
#
# | Parameter    | Default | Meaning                |
# | ------------ | ------- | ---------------------- |
# | `io`         | —       | File path              |
# | `sheet_name` | `0`     | Sheet name or index    |
# | `usecols`    | `None`  | Columns to read        |
# | `skiprows`   | `None`  | Rows to skip           |
# | `nrows`      | `None`  | Number of rows to read |
# | `dtype`      | `None`  | Force column types     |
# | `engine`     | `None`  | `'openpyxl'`, `'xlrd'` |

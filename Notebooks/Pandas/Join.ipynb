# %% [markdown]
# # **Join**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ###  `df.join()` — **Index-based join**
#
# #### 👉 Important Parameters
#
# | Parameter | Default  | Meaning                                   |
# | --------- | -------- | ----------------------------------------- |
# | `other`   | —        | DataFrame to join                         |
# | `on`      | `None`   | Join key if not index                     |
# | `how`     | `'left'` | `'left'`, `'right'`, `'inner'`, `'outer'` |
# | `lsuffix` | `''`     | Left suffix for conflicts                 |
# | `rsuffix` | `''`     | Right suffix for conflicts                |
#
# 📌 **Best when index is meaningful**
#
# **Columns CAN NOT have overlaping name**

# %%
df1=pd.DataFrame({'A':[1,2,3,4,5],'B':[11,12,13,14,15]})
df2=pd.DataFrame({'C':[21,22,23,25],'D':[31,32,33,35]})

df1.join(df2)
# df2.join(df1)

# users = pd.DataFrame({'name': ['Ali', 'Sara', 'Usman']}, index=[1, 2, 3])
# scores = pd.DataFrame({'score': [85, 90]}, index=[1, 3])
# users.join(scores)

# users = pd.DataFrame({'name': ['Ali', 'Sara', 'Usman','Haroon']}, index=['a','b','c','d'])
# scores = pd.DataFrame({'score': [85, 90]})
# users.join(scores)


# users = pd.DataFrame({'name': ['Ali', 'Sara', 'Usman','Haroon']}, index=['a','b','c','d'])
# scores = pd.DataFrame({'score': [85, 90]}, index=['a','d'])
# users.join(scores)
# Out:
#    A   B     C     D
# 0  1  11  21.0  31.0
# 1  2  12  22.0  32.0
# 2  3  13  23.0  33.0
# 3  4  14  25.0  35.0
# 4  5  15   NaN   NaN

# %% [markdown]
# ## `how= left/right/inner/outer` -- **Parameter**

# %%
users = pd.DataFrame({'name': ['Ali', 'Sara', 'Usman','Haroon']}, index=['a','b','c','d'])
scores = pd.DataFrame({'score': [85, 90]}, index=['a','d'])

# %%
# show rows according to indexes of left table
users.join(scores,how='left')
# Out:
#      name  score
# a     Ali   85.0
# b    Sara    NaN
# c   Usman    NaN
# d  Haroon   90.0

# %%
# show rows according to indexes of right table
users.join(scores,how='right')
# Out:
#      name  score
# a     Ali     85
# d  Haroon     90

# %%
# inner : Intersection
users.join(scores,how='inner')
# Out:
#      name  score
# a     Ali     85
# d  Haroon     90

# %%
# outer : Union
users.join(scores,how='outer')
# Out:
#      name  score
# a     Ali   85.0
# b    Sara    NaN
# c   Usman    NaN
# d  Haroon   90.0

# %% [markdown]
# ## `suffix : lsuffix / rsuffix` -- **Parameter**

# %%
left = pd.DataFrame({'name': ['Ali', 'Sara', 'Usman','Haroon']}, index=['a','b','c','d'])
right= pd.DataFrame({'name': ['Aisha','Areeba','Aleena','Areesha']}, index=['a','b','c','d'])

# %%
left.join(right,lsuffix='_Left')
left.join(right,rsuffix='_Right')
# left.join(right,lsuffix='_Left , rsuffix='_Right')
# Out:
#      name name_Right
# a     Ali      Aisha
# b    Sara     Areeba
# c   Usman     Aleena
# d  Haroon    Areesha

# %% [markdown]
# ---
# # **Practice Problems**

# %%
employees = pd.DataFrame({
    'EmpID': [101, 102, 103, 104, 105],
    'Name': ['Ali', 'Sara', 'Ahmed', 'Zara', 'Usman'],
    'DeptID': [1, 2, 1, 3, 2]
})

salaries = pd.DataFrame({
    'EmpID': [101, 102, 104],
    'Salary': [50000, 60000, 55000]
})
# 📘 Dataset F — Employee Info (Indexed)
emp_info = employees.set_index('EmpID')
# 📘 Dataset G — Salary Info (Indexed)

sal_info = salaries.set_index('EmpID')

# %% [markdown]
# ---
# ### 🧠 Problem 1
#
# Join `emp_info` and `sal_info` so that:
#
# * All employees remain
# * Salary appears where available

# %%
emp_info.join(sal_info,how='left')
# Out:
#         Name  DeptID   Salary
# EmpID
# 101      Ali       1  50000.0
# 102     Sara       2  60000.0
# 103    Ahmed       1      NaN
# 104     Zara       3  55000.0
# 105    Usman       2      NaN

# %% [markdown]
# ### 🧠 Problem 2
#
# Change join type so that **only employees with salary** appear.

# %%
emp_info.join(sal_info,how='inner')
# Out:
#        Name  DeptID  Salary
# EmpID
# 101     Ali       1   50000
# 102    Sara       2   60000
# 104    Zara       3   55000

# %% [markdown]
# ### 🧠 Problem 3
#
# Why would `join()` be cleaner than `merge()` in this case?
# (Answer in words, not code)

# %% [markdown]
# **Because `merge()` is like SQL join it merges based on the matching columns while `join()` joins based on the  matching index**
#
# ✅ Answer (conceptual)
#
# * Keys already in index
#
# * No need for `on=`, `left_on=`, `right_on=`
#
# * Less error-prone
#
# * More readable for index-aligned data
#
# 👉 `join()` = semantic clarity when indexes matter

# %% [markdown]
# ---
# # 🔥 10 HARD & TRICKY `join()` PROBLEMS

# %%
# 📘 Dataset 1 — Index Mismatch
df_a = pd.DataFrame({
    'Name': ['Ali', 'Sara', 'Ahmed'],
    'Dept': ['IT', 'HR', 'IT']
}, index=[101, 102, 103])

df_b = pd.DataFrame({
    'Salary': [50000, 60000, 55000]
}, index=[102, 103, 104])

# %% [markdown]
# ### 🧩 Problem 1
#
# Join `df_a` and `df_b`.
#
# * Explain why NaN appears
# * Identify which rows mismatched

# %%
df_a.join(df_b)
df_a.join(df_b).count()
df_a.join(df_b,how='inner')
# Out:
#       Name Dept  Salary
# 102   Sara   HR   50000
# 103  Ahmed   IT   60000

# %% [markdown]
# **Ans: Because `df_b` has no index as 101**

# %%
# 📘 Dataset 2 — Duplicate Index

df_c = pd.DataFrame({
    'Score': [80, 85, 90]
}, index=[101, 101, 102])

# %% [markdown]
# ### 🧩 Problem 2
#
# Join `df_a` with `df_c`.
#
# * Observe row count
# * Explain duplication

# %%
df_a.join(df_c)
df_a.join(df_c)['Name'].value_counts()
# Out:
#       Name Dept  Score
# 101    Ali   IT   80.0
# 101    Ali   IT   85.0
# 102   Sara   HR   90.0
# 103  Ahmed   IT    NaN

# %% [markdown]
# **`df_c` has duplicate index 101**

# %%
## 📘 Dataset 3 — Join with Series
bonus = pd.Series(
    [5000, 7000],
    index=[101, 103],
    name='Bonus'
)

# %% [markdown]
# ### 🧩 Problem 3
#
# Join `df_a` with `bonus`.
#
# * What happens to column name?
# * Why is this useful?

# %%
df_a.join(bonus)
# Out:
#       Name Dept   Bonus
# 101    Ali   IT  5000.0
# 102   Sara   HR     NaN
# 103  Ahmed   IT  7000.0

# %% [markdown]
# ### 📘 Dataset 4 — Join Multiple DataFrames
#
# ---
#
# ### 🧩 Problem 4
#
# Join `df_a` with `df_b` **and** `bonus` in one statement.
#
# (Hint: list of DataFrames)

# %%
dfs=[df_b,bonus]
df_a.join(dfs)
# Out:
#       Name Dept   Salary   Bonus
# 101    Ali   IT      NaN  5000.0
# 102   Sara   HR  50000.0     NaN
# 103  Ahmed   IT  60000.0  7000.0

# %%
## 📘 Dataset 5 — Index Type Trap

df_d = pd.DataFrame({
    'Salary': [50000, 60000]
}, index=['101', '102'])   # strings!

# %% [markdown]
# ### 🧩 Problem 5
#
# Join `df_a` with `df_d`.
#
# * Why does NOTHING match?
# * How do you fix it?

# %%
df_a.join(df_d)
df_d.index=df_d.index.astype(int)
df_a.join(df_d)
# Out:
#       Name Dept   Salary
# 101    Ali   IT  50000.0
# 102   Sara   HR  60000.0
# 103  Ahmed   IT      NaN

# %%
## 📘 Dataset 6 — Join with Suffixes
df_e = pd.DataFrame({
    'Dept': ['IT', 'HR']
}, index=[101, 102])

# %% [markdown]
# ### 🧩 Problem 6
#
# Join `df_a` and `df_e`.
#
# * What error occurs?
# * **Ans: Because There is overlaping column Name `Dept`**
# * Fix it properly

# %%
df_a.join(df_e,lsuffix='_Left',rsuffix='_Right') # Fix
# Out:
#       Name Dept_Left Dept_Right
# 101    Ali        IT         IT
# 102   Sara        HR         HR
# 103  Ahmed        IT        NaN

# %% [markdown]
# ### 📘 Dataset 7 — Outer Join Logic
#
# ---
#
# ### 🧩 Problem 7
#
# Perform an **outer join** between `df_a` and `df_b`.
#
# * Identify rows that come only from right DataFrame

# %%
df_a.join(df_b,how='outer')
# Out:
#       Name Dept   Salary
# 101    Ali   IT      NaN
# 102   Sara   HR  50000.0
# 103  Ahmed   IT  60000.0
# 104    NaN  NaN  55000.0

# %% [markdown]
# ### 📘 Dataset 8 — Join vs Merge Trap
#
# ---
#
# ### 🧩 Problem 8
#
# Rewrite this using `join()`:
#
# ```python
# pd.merge(df_a, df_b, left_index=True, right_index=True)
# ```
#
# Explain **why `join()` is cleaner**.

# %%
pd.merge(df_a,df_b,left_index=True,right_index=True)
df_a.join(df_b,how='inner')
# Out:
#       Name Dept  Salary
# 102   Sara   HR   50000
# 103  Ahmed   IT   60000

# %% [markdown]
# ### 📘 Dataset 9 — Validate Logic (Advanced)
#
# ---
#
# ### 🧩 Problem 9
#
# Use `join()` logic to **detect duplicate index values** before joining.
#
# (Hint: index properties)

# %%
df_c.index.is_unique
df_c.index.duplicated()
df_c.index[df_c.index.duplicated()]
# Out:
# array([False,  True, False])

# %% [markdown]
# ### 📘 Dataset 10 — Real-World Bug
#
# ---
#
# ### 🧩 Problem 10
#
# Your join result suddenly doubles rows after adding new data.
#
# * What caused this?
# * How do you prevent it permanently?

# %%
df = pd.DataFrame({
    'Status': ['Shipped', 'Pending', 'Cancelled']
}, index=[100, 101, 100])
df.index.name='index_col'

# %%
df = df.reset_index().drop_duplicates(subset='index_col').set_index('index_col')
df
# OR
# assert df.index.is_unique
# Out:
#             Status
# index_col
# 100        Shipped
# 101        Pending

# %% [markdown]
# # **Concat**
#
# ###  `pd.concat()` — **Stack or append data**
#
# ### 👉 Important Parameters
#
# | Parameter      | Default   | Meaning                   |
# | -------------- | --------- | ------------------------- |
# | `objs`         | —         | List of DataFrames        |
# | `axis`         | `0`       | `0` → rows, `1` → columns |
# | `ignore_index` | `False`   | Reset index               |
# | `join`         | `'outer'` | `'outer'` or `'inner'`    |
# | `keys`         | `None`    | Create hierarchical index |

# %%
import pandas as pd

# %%
ser1=pd.Series([1,2,3,4])
ser2=pd.Series([11,12,13,14])

# %%
pd.concat([ser1,ser2])
# Out:
# 0     1
# 1     2
# 2     3
# 3     4
# 0    11
# 1    12
# 2    13
# 3    14
# dtype: int64

# %%
df1=pd.DataFrame({'Name':['Haroon','Moiz','Moin','Sami'],'Dept':['CS','IT','SE','IT']})
df2=pd.DataFrame({ 'Name':['Ali','Jawad'],'Dept':['HR','FINANCE']})

# %%
df1=pd.DataFrame({ 'Name':['Ali','Jawad']})
df2=pd.DataFrame({'Name':['Haroon','Moiz','Moin','Sami'],'Dept':['CS','IT','SE','IT']})

pd.concat([df1,df2])
pd.concat([df1,df2],axis=1)
# Out:
#     Name    Name Dept
# 0    Ali  Haroon   CS
# 1  Jawad    Moiz   IT
# 2    NaN    Moin   SE
# 3    NaN    Sami   IT

# %%
df1=pd.DataFrame({ 'B':[1,2,3,4,5]})
df2=pd.DataFrame({'A':[11,22,33,44],'C':[55,66,77,88]})
pd.concat([df1,df2])
pd.concat([df1,df2],axis=1)
# Out:
#    B     A     C
# 0  1  11.0  55.0
# 1  2  22.0  66.0
# 2  3  33.0  77.0
# 3  4  44.0  88.0
# 4  5   NaN   NaN

# %%
# Row Wise Concatenation
pd.concat([df1,df2])
# Out:
#      B     A     C
# 0  1.0   NaN   NaN
# 1  2.0   NaN   NaN
# 2  3.0   NaN   NaN
# 3  4.0   NaN   NaN
# 4  5.0   NaN   NaN
# 0  NaN  11.0  55.0
# 1  NaN  22.0  66.0
# 2  NaN  33.0  77.0
# 3  NaN  44.0  88.0

# %% [markdown]
# ### `axis = 0/1`

# %%
# Column Wise Concatenation
pd.concat([df1,df2],axis=1)
# Out:
#    B     A     C
# 0  1  11.0  55.0
# 1  2  22.0  66.0
# 2  3  33.0  77.0
# 3  4  44.0  88.0
# 4  5   NaN   NaN

# %% [markdown]
# ### `join = 'inner/outer'`-- **Parameter**
# **Outer : Union (All Rows)**
#
# **Inner : Intersection (Overlapping/common Indexes only)**

# %%
pd.concat([df1,df2],axis=1,join='inner')
# Out:
#    B   A   C
# 0  1  11  55
# 1  2  22  66
# 2  3  33  77
# 3  4  44  88

# %%
pd.concat([df1,df2],axis=1,join='outer')
# Out:
#    B     A     C
# 0  1  11.0  55.0
# 1  2  22.0  66.0
# 2  3  33.0  77.0
# 3  4  44.0  88.0
# 4  5   NaN   NaN

# %% [markdown]
# ### `key=["labels"]` --**Parameter, Creates hierarchical Labels**

# %%
pd.concat([df1,df2],axis=1,keys=['Df1','Df2'])
# Out:
#   Df1   Df2
#     B     A     C
# 0   1  11.0  55.0
# 1   2  22.0  66.0
# 2   3  33.0  77.0
# 3   4  44.0  88.0
# 4   5   NaN   NaN

# %%
pd.concat([df1,df2],axis=0,keys=['Df1','Df2'])
# Out:
#          B     A     C
# Df1 0  1.0   NaN   NaN
#     1  2.0   NaN   NaN
#     2  3.0   NaN   NaN
#     3  4.0   NaN   NaN
#     4  5.0   NaN   NaN
# Df2 0  NaN  11.0  55.0
#     1  NaN  22.0  66.0
#     2  NaN  33.0  77.0
#     3  NaN  44.0  88.0

# %% [markdown]
# ---
# # **Practice Problems**

# %%
jan = pd.DataFrame({
    'Product': ['Pen', 'Book'],
    'Units': [100, 150]
})
feb = pd.DataFrame({
    'Product': ['Pen', 'Book'],
    'Units': [120, 130]
})

# %% [markdown]
# ### 🧠 Problem 1
#
# Combine January and February sales into **one DataFrame**:
#
# * Row-wise
# * Reset index properly

# %%
pd.concat([jan,feb],axis=0,ignore_index=True)
# Out:
#   Product  Units
# 0     Pen    100
# 1    Book    150
# 2     Pen    120
# 3    Book    130

# %% [markdown]
# ### 🧠 Problem 2
#
# Add a column `Month` **before concatenation** so final data shows:
#
# > Product | Units | Month

# %%
feb['Month']='Feb'
jan['Month']='Jan'
pd.concat([jan,feb],axis=0,ignore_index=True)
# Out:
#   Product  Units Month
# 0     Pen    100   Jan
# 1    Book    150   Jan
# 2     Pen    120   Feb
# 3    Book    130   Feb

# %% [markdown]
# ### 🧠 Problem 3
#
# What happens if you concat `jan` and `feb` **column-wise**?
# Try it and **explain the result**.

# %%
pd.concat([jan,feb],axis=1)
# Out:
#   Product  Units Month Product  Units Month
# 0     Pen    100   Jan     Pen    120   Feb
# 1    Book    150   Jan    Book    130   Feb

# %% [markdown]
# **Columns are glued side-by-side**

# %% [markdown]
# ---
# # 🔥 **10 HARD & TRICKY CONCAT PROBLEMS**

# %%
# 📘 Dataset 1 — Schema Mismatch
df1 = pd.DataFrame({
    'ID': [1, 2],
    'Name': ['Ali', 'Sara'],
    'Salary': [50000, 60000]
})

df2 = pd.DataFrame({
    'ID': [3, 4],
    'Name': ['Ahmed', 'Zara']
})

# %% [markdown]
# ### 🧩 Problem 1
#
# Concat `df1` and `df2` row-wise.
#
# * Observe missing values
# * Explain **why NaN appears**

# %%
pd.concat([df1,df2],axis=0,ignore_index=True)
# Out:
#    ID   Name   Salary
# 0   1    Ali  50000.0
# 1   2   Sara  60000.0
# 2   3  Ahmed      NaN
# 3   4   Zara      NaN

# %% [markdown]
# **Ans: Becuase There is NO Salary column in df2**

# %%
# 📘 Dataset 2 — Duplicate Index Trap
df3 = pd.DataFrame({
    'Product': ['Pen', 'Book'],
    'Units': [100, 150]
}, index=[0, 0])

# %% [markdown]
# ### 🧩 Problem 2
#
# Concat `df3` with itself.
#
# * Observe index
# * Fix index issue properly

# %%
pd.concat([df3,df3],ignore_index=True)
# Out:
#   Product  Units
# 0     Pen    100
# 1    Book    150
# 2     Pen    100
# 3    Book    150

# %%
# 📘 Dataset 3 — Column Order Confusion
df4 = pd.DataFrame({
    'A': [1, 2],
    'B': [3, 4]
})

df5 = pd.DataFrame({
    'B': [5, 6],
    'A': [7, 8]
})

# %% [markdown]
# ### 🧩 Problem 3
#
# Concat `df4` and `df5` row-wise.
#
# * Does Pandas respect column order?
# * Why?

# %%
pd.concat([df4,df5],ignore_index=True)
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 2  7  5
# 3  8  6

# %% [markdown]
# **Ans: Yes, Pandas aligns by column name, NOT Postional stacking.**

# %%
# 📘 Dataset 4 — Outer vs Inner

df6 = pd.DataFrame({
    'A': [1, 2],
    'B': [3, 4]
})

df7 = pd.DataFrame({
    'B': [5, 6],
    'C': [7, 8]
})

# %% [markdown]
# ### 🧩 Problem 4
#
# Concat row-wise using:
#
# 1️⃣ default behavior
#
# 2️⃣ `join='inner'`
#
# Explain difference.

# %%
pd.concat([df6,df7],ignore_index=True)
pd.concat([df6,df7],join='inner',ignore_index=True)
# Out:
#    B
# 0  3
# 1  4
# 2  5
# 3  6

# %% [markdown]
# **Ans: `join='inner'` concates only intersecting data**

# %%
#📘 Dataset 5 — Hierarchical Index

q1 = pd.DataFrame({'Sales': [100, 200]}, index=['Jan', 'Feb'])
q2 = pd.DataFrame({'Sales': [150, 250]}, index=['Mar', 'Apr'])

# %% [markdown]
# ### 🧩 Problem 5
#
# Concat while keeping **month source info** in index.
#
# (Hint: `keys=`)

# %%
pd.concat([q1,q2],keys=['q1','q2'])
# Out:
#         Sales
# q1 Jan    100
#    Feb    200
# q2 Mar    150
#    Apr    250

# %%
# 📘 Dataset 6 — Column-wise Alignment Trap

left = pd.DataFrame({'A': [1, 2]}, index=[0, 1])
right = pd.DataFrame({'B': [3, 4]}, index=[1, 2])

# %% [markdown]
# ### 🧩 Problem 6
#
# Concat column-wise.
#
# * Explain missing values
# * Fix alignment issue

# %%
pd.concat([left.reset_index(drop=True),right.reset_index(drop=True)],axis=1)
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
# 📘 Dataset 7 — Real-World File Combine
files = [jan, feb]

# %% [markdown]
# ### 🧩 Problem 7
#
# Simulate combining **multiple monthly files** safely.
#
# * Avoid index problems
# * Maintain row order

# %%
pd.concat(files,ignore_index=True)
# Out:
#   Product  Units Month
# 0     Pen    100   Jan
# 1    Book    150   Jan
# 2     Pen    120   Feb
# 3    Book    130   Feb

# %%
# 📘 Dataset 8 — Performance Trap
dfs = [df1, df2, df4, df5]

# %% [markdown]
# ### 🧩 Problem 8
#
# Why is this BAD?
#
# ```python
# result = pd.DataFrame()
# for d in dfs:
#     result = pd.concat([result, d])
# ```
#
# Rewrite correctly.

# %%
result=pd.DataFrame()
for d in dfs:
    result=pd.concat([result,d ])
result

# Bad Time-complexity
# Out:
#     ID   Name   Salary    A    B
# 0  1.0    Ali  50000.0  NaN  NaN
# 1  2.0   Sara  60000.0  NaN  NaN
# 0  3.0  Ahmed      NaN  NaN  NaN
# 1  4.0   Zara      NaN  NaN  NaN
# 0  NaN    NaN      NaN  1.0  3.0
# 1  NaN    NaN      NaN  2.0  4.0
# 0  NaN    NaN      NaN  7.0  5.0
# 1  NaN    NaN      NaN  8.0  6.0

# %%
result1=pd.concat(dfs,ignore_index=True)
result1
# Out:
#     ID   Name   Salary    A    B
# 0  1.0    Ali  50000.0  NaN  NaN
# 1  2.0   Sara  60000.0  NaN  NaN
# 2  3.0  Ahmed      NaN  NaN  NaN
# 3  4.0   Zara      NaN  NaN  NaN
# 4  NaN    NaN      NaN  1.0  3.0
# 5  NaN    NaN      NaN  2.0  4.0
# 6  NaN    NaN      NaN  7.0  5.0
# 7  NaN    NaN      NaN  8.0  6.0

# %% [markdown]
# ## 📘 Dataset 9 — Mixed Axis Confusion
#
# ---
#
# ### 🧩 Problem 9
#
# Explain difference between:
#
# ```python
# pd.concat([df4, df5], axis=0)
# pd.concat([df4, df5], axis=1)
# ```
#
# Without running code.

# %% [markdown]
# `axis=0` will concate row-wise
#
# `axis=1` will glue side-by-side both dataframes

# %% [markdown]
# ## 📘 Dataset 10 — Debugging Case
#
# ---
#
# ### 🧩 Problem 10
#
# You expected **4 rows** but got **6 rows** after concat.
#
# * What caused this?
# * How do you fix it?

# %%
df_1=pd.DataFrame({'Name':['Haroon','Laiba','Ali']},index=[1,2,1])
df_2=pd.DataFrame({'Name':['Ali','Ali','Sara']},index=[1,1,2])
concated=pd.concat([df_1,df_2],ignore_index=True)
concated=concated.drop_duplicates().reset_index(drop=True)
concated
# Out:
#      Name
# 0  Haroon
# 1   Laiba
# 2     Ali
# 3    Sara
